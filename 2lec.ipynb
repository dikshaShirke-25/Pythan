# %%
greet="hello world"
print(greet[::-1])
# Out:
# dlrow olleh

# %%
a=2
b=3
print(a**2+b**2+2*2*3)
# Out:
# 25

# %%
a=int(input("enter sub1: "))
b=int(input("enter sub2: "))
c=int(input("enter sub3: "))
d=int(input("enter sub4: "))
e=int(input("enter sub5: "))
per=((a+b+c+d+e)/5)
print(per)
# Out:
# enter sub1: 88
# enter sub2: 52
# enter sub3: 66
# enter sub4: 95
# enter sub5: 78
# 75.8

# %%
age=18
if(age>=18):
   print("eligible"),
else:
   print("not eligible"),
print("apply latter")
# Out:
# eligible
# apply latter

# %%
a=int(input("num1"))
b=int(input("num2"))
if(a>b):
   print("a is greater than b"),
else:
   print("b is greater than a"),
print("a is lesser than b")
# Out:
# num154
# num277
# b is greater than a
# a is lesser than b

# %%
a=int(input("num1"))
b=int(input("num2"))
if(a>b):
   print("a is greater"),
elif (b>a):
   print("b is greater"),
else:
   print("both are equal"),
# Out:
# num133
# num233
# both are equal
# a is lesser than b

# %%
a=a
b='b'
if(a:=b):
   print("success")
else:
   print("not success")
# Out:
# success

# %%
sub1= int(input("enter 1st subject:"))
sub2= int(input("enter 2nd subject:"))
sub3= int(input("enter 3rd subject:"))
sub4= int(input("enter 4th subject:"))
sub5= int(input("enter 5th subject:"))
per=(sub1+sub2+sub3+sub4+sub5)/500*100
print(per,"%")
if per<0:
    print("AUR PHONE CHALAO")
elif per<35:
    print("fail")
elif per<40:
    print("pass")
elif per<60:
    print("second class")
elif per<75:
    print("first class")
elif per>101:
    print("not applicable")
else:
    print("distinction")
# Out:
# enter 1st subject:22
# enter 2nd subject:20
# enter 3rd subject:30
# enter 4th subject:0
# enter 5th subject:50
# 24.4 %
# fail
